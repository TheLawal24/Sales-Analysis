# %% [markdown]
# ## Import Neccesary Analysis

# %%
import  pandas as pd
import os

# %% [markdown]
# Task #1: Merging 12 months of sales data into a single csv file

# %%
df = pd.read_csv("./Sales_Data/Sales_April_2019.csv")

files = [file for file in os.listdir('./Sales_Data')]

for file in files:
    print(file)
# Out:
# Sales_April_2019.csv
# Sales_August_2019.csv
# Sales_December_2019.csv
# Sales_February_2019.csv
# Sales_January_2019.csv
# Sales_July_2019.csv
# Sales_June_2019.csv
# Sales_March_2019.csv
# Sales_May_2019.csv
# Sales_November_2019.csv
# Sales_October_2019.csv
# Sales_September_2019.csv

# %%
df = pd.read_csv("./Sales_Data/Sales_April_2019.csv")

files = [file for file in os.listdir('./Sales_Data')]

all_months_data = pd.DataFrame()

for file in files:
    df = pd.read_csv('./Sales_Data/'+file)
    all_months_data = pd.concat([all_months_data, df])
    
all_months_data.to_csv("all_data.csv", index = False)

# %% [markdown]
# Read in updated Data Frame

# %%
all_data = pd.read_csv('all_data.csv')
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %% [markdown]
# ### Clean up the data

# %% [markdown]
# Task #2: Add More Column

# %%
all_data.head(200)
# Out:
#     Order ID                     Product Quantity Ordered Price Each  \
# 0     176558        USB-C Charging Cable                2      11.95
# 1        NaN                         NaN              NaN        NaN
# 2     176559  Bose SoundSport Headphones                1      99.99
# 3     176560                Google Phone                1        600
# 4     176560            Wired Headphones                1      11.99
# ..       ...                         ...              ...        ...
# 195   176744    Lightning Charging Cable                1      14.95
# 196   176745            Wired Headphones                1      11.99
# 197   176746      27in 4K Gaming Monitor                1     389.99
# 198   176747          Macbook Pro Laptop                1       1700
# 199   176748               Flatscreen TV                1        300
#
#          Order Date                      Purchase Address  Months
# 0    04/19/19 08:46          917 1st St, Dallas, TX 75001     NaN
# 1               NaN                                   NaN     NaN
# 2    04/07/19 22:30     682 Chestnut St, Boston, MA 02215     NaN
# 3    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     NaN
# 4    04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001     NaN
# ..              ...                                   ...     ...
# 195  04/14/19 19:59   937 Maple St, Los Angeles, CA 90001     NaN
# 196  04/24/19 09:23   461 Adams St, Los Angeles, CA 90001     NaN
# 197  04/08/19 19:04        638 Park St, Seattle, WA 98101     NaN
# 198  04/27/19 15:04   645 7th St, San Francisco, CA 94016     NaN
# 199  04/24/19 15:28         339 13th St, Boston, MA 02215     NaN
#
# [200 rows x 7 columns]
